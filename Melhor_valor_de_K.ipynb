# %% [markdown]
# <a href="https://colab.research.google.com/github/edvanaraujo/Pythonsimples/blob/main/Melhor_valor_de_K.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt

from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score

# %%
iris = load_iris()

X = iris.data
y = iris.target

# %%
x_train, x_test, y_train, y_test = train_test_split(
    X,
    y,
    test_size=0.20

)

# %%
accuracy = []
for k in range(1,21):

    knn = KNeighborsClassifier(n_neighbors=k)

    knn.fit(x_train, y_train)

    previsoes = knn.predict(x_test)



    acc = accuracy_score(y_test, previsoes)

    accuracy.append(acc)

# %%
plt.figure(figsize=(8,5))

plt.plot(range(1,21), accuracy)

plt.xlabel("Valor de K")

plt.ylabel("Accuracy")

plt.title("Accuracy x Valor de K")

plt.grid()

plt.show()
